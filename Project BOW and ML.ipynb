# %%
import pandas as pd
import numpy as np
import utility
import re
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import SGDClassifier
import pickle

# %%
data =  pd.read_csv('Data/data_no_duplicates.csv', sep=',')
data
# Out:
#       Unnamed: 0    id                                               text  \
# 0              0     1  Please tell me why the bitch next to me in the...
# 1              1     3      @abzdafab Dear cunt, please shut the fuck up.
# 2              2     4    RT @queenofdragonsb: Pls shut the fuck up bitch
# 3              3     5  RT @21bIvck: "when u gonna get your license" S...
# 4              4     6  @SarahhWaqar @CallmeJaagii Bitch shut the fuck up
# 5              5     7  ok babies i'll go to sleep ok bitch shut the f...
# 6              6     8  You are a fucking ugly bitch!shut the fuck up?...
# 7              7     9  RT @bnixole: bitch shut the fuck up you're fuc...
# 8              8    10  RT @vaintshit:  shut the fuck up and come suck...
# 9              9    11  @AnisaJomha ice has more talent in his ejecula...
# 10            10    12  @ArianasBotch Ok if you fucking said leave blo...
# 11            11    13    @LadyNadiaEssex Shut the fuck up ye little slag
# 12            12    14  Selena has BEEN acting like she'ss the victim ...
# 13            13    15                @Sundae_3 Shut the fuck up you cunt
# 14            14    16  like damn bitch if youre hungry shut the fuck ...
# 15            15    17  RT @Akhdre_: "You too skinny, imma hurt you" G...
# 16            16    18  @sofiasfaIcones shut the fuck up hes not gonna...
# 17            17    19  Don't speak bitch,just Die Die Die Why can't y...
# 18            18    20  If women want equailty they should be drafted ...
# 19            19    21  charli: fuck you bitch charli: omg why am i so...
# 20            20    22     Bitch you better be 😂😂 https://t.co/8YaXVNzhcg
# 21            21    23  @saima55016154 Come on box I show you my cock ...
# 22            22    24  Rica gets so much cock in her licked cunt http...
# 23            23    25                       Say you gon ride, bitch ride
# 24            24    26  @thereallisaann bitch you a hoe... I do not li...
# 25            25    27    They call it HB. I’m a hot bitch you a has been
# 26            26    28  I kno this bitch pussy smells really bad becau...
# 27            27    29  @Davidsalas87 Cause you're a Bitch and you lov...
# 28            28    30  cuf yo boy and yo girl Have you heard ‘pull a ...
# 29            29    31  @ashitudeprobs You know you can always block m...
# ...          ...   ...                                                ...
# 3967        3967  4039  @3kad3 @JesusInAmerica @PF_Olson @eoghanmcderm...
# 3968        3968  4040  Absolutely shameful 27 month sentence!! Woman ...
# 3969        3969  4041  I don’t know one woman who has not experienced...
# 3970        3970  4042  Male logic is a woman should get life for accu...
# 3971        3971  4043  If any woman is a victim of sexual assault I p...
# 3972        3972  4044  Doing an even bigger eyeroll at the 'famous' T...
# 3973        3973  4045  Brilliant, stone a woman after rape, there is ...
# 3974        3974  4046  #WorldFoodDay Thank you for celebrating Sri Fo...
# 3975        3975  4047  Even if a woman goes to a nude beach .. doesnt...
# 3976        3976  4048  This is what's so worrying. At one end, asking...
# 3977        3977  4049  #Nigeria #news - Family of nine #Iraqi asylum ...
# 3978        3978  4050  THINGS GOT HEATED: BREAKING: Woman Sets Pedoph...
# 3979        3979  4051  @kellyhamilton49 @BachynskiBomber @SethAbramso...
# 3980        3980  4052  Also just because a woman has been drinking is...
# 3981        3981  4053  @MCNMG @SethAbramson Says the woman who votes ...
# 3982        3982  4054  @JackyHolyoake @FireWomon See you are doing it...
# 3983        3983  4055  @deBeauxOs1 I cannot imagine any woman who doe...
# 3984        3984  4056  5 Tunisians try to rape Lampedusa woman (3) ht...
# 3985        3985  4057  The @IEBCKenya as currently constituted is mer...
# 3986        3986  4058  @LiquidHbox u fucking cunt u wanna fuck me duc...
# 3987        3987  4059  Giving You A Sneak Peak Of Her Hot Little Cunt...
# 3988        3988  4060  Looooooooool I can’t believe ‘BEN WOTTS’ aka d...
# 3989        3989  4061  k i come on to twitter to make fun of you but ...
# 3990        3990  4062          @watermeloser Also cunt hole is redundant
# 3991        3991  4063  Getting my monster prolapsed cunt totally fuck...
# 3992        3992  4064  FYI. Mariah rhymes with Pariah which in German...
# 3993        3993  4065  Johnny Castle loves always wet warm fuck hole ...
# 3994        3994  4066  @DonCannon @DJDRAMA Ole fat neck ass nigha . R...
# 3995        3995  4067  Xd @Idubbbz tight hole lost <3 Kids @metpolice...
# 3996        3996  4068  @jonoread @Davee8989 Fat cunt most likely made...
#
#       misogynous  misogyny_category   target
# 0              1          dominance   active
# 1              1          dominance   active
# 2              1          dominance   active
# 3              1          dominance   active
# 4              1          dominance   active
# 5              1          dominance  passive
# 6              1          dominance   active
# 7              1          dominance   active
# 8              1  sexual_harassment   active
# 9              1  sexual_harassment   active
# 10             1  sexual_harassment   active
# 11             1          dominance   active
# 12             1          derailing  passive
# 13             1          dominance   active
# 14             1          dominance   active
# 15             1  sexual_harassment   active
# 16             1          dominance   active
# 17             1          dominance   active
# 18             1          derailing  passive
# 19             1          discredit   active
# 20             1          discredit   active
# 21             1  sexual_harassment   active
# 22             1  sexual_harassment   active
# 23             1          discredit   active
# 24             1          discredit   active
# 25             1          discredit   active
# 26             1          discredit   active
# 27             1          discredit   active
# 28             1          discredit  passive
# 29             1          discredit   active
# ...          ...                ...      ...
# 3967           0                  0        0
# 3968           0                  0        0
# 3969           0                  0        0
# 3970           0                  0        0
# 3971           0                  0        0
# 3972           0                  0        0
# 3973           0                  0        0
# 3974           0                  0        0
# 3975           0                  0        0
# 3976           0                  0        0
# 3977           0                  0        0
# 3978           0                  0        0
# 3979           0                  0        0
# 3980           0                  0        0
# 3981           0                  0        0
# 3982           0                  0        0
# 3983           0                  0        0
# 3984           0                  0        0
# 3985           0                  0        0
# 3986           0                  0        0
# 3987           0                  0        0
# 3988           0                  0        0
# 3989           0                  0        0
# 3990           0                  0        0
# 3991           0                  0        0
# 3992           0                  0        0
# 3993           0                  0        0
# 3994           0                  0        0
# 3995           0                  0        0
# 3996           0                  0        0
#
# [3997 rows x 6 columns]

# %%
# preprocess text: to lower case, http instead of a full link, @ instead of a full @-mention
utility.text_preprocessing(data, 'text')
# transform emoji to text
utility.demojize(data, 'text')

# %% [markdown]
# # Misogyny Detection

# %% [markdown]
# ## Count Vectorizer + ML Models

# %%
# split data into train and test sets
split = StratifiedShuffleSplit(test_size = 0.1, random_state = 42)
for train_index, test_index in split.split(data, data[['misogynous', 'misogyny_category', 'target']]):
    train = data.loc[train_index]
    test = data.loc[test_index]

# %%
# convert tweets to a matrix of unigrams and bigrams counts
count_vect_misogyny = CountVectorizer(ngram_range=(1, 2))
X_train = count_vect_misogyny.fit_transform(train['text'])
X_test = count_vect_misogyny.transform(test['text'])

# %%
# logistic regression
lg = LogisticRegression(max_iter = 10000)
param_grid = {'C': [0.1, 0.01, 0.001, 0.0001]}
grid_search_lg = GridSearchCV(lg, cv = 10, param_grid = param_grid, scoring = 'accuracy', n_jobs = 3)
grid_search_lg.fit(X_train, train['misogynous'])
print(grid_search_lg.best_estimator_)
print(grid_search_lg.best_score_)
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=10000, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# 0.780650542118432

# %%
# random forest
forest = RandomForestClassifier()
param_grid = {'max_depth': [155, 165, 175],
             'n_estimators': [200]}
grid_search_forest = GridSearchCV(forest, cv = 10, param_grid = param_grid, scoring = 'accuracy', n_jobs = 3)
grid_search_forest.fit(X_train, train['misogynous'])
print(grid_search_forest.best_estimator_)
print(grid_search_forest.best_score_)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=175, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 0.7867667500695024

# %%
# SGD classifier
sgdc = SGDClassifier()
param_grid = {'loss': ['hinge', 'log'],
             'penalty': ['l2', 'l1'],
             'alpha': [0.001, 0.0001, 0.00001]}
grid_search_sgdc = GridSearchCV(sgdc, cv = 10, param_grid = param_grid, scoring = 'accuracy', n_jobs = 3)
grid_search_sgdc.fit(X_train, train['misogynous'])
print(grid_search_sgdc.best_estimator_)
print(grid_search_sgdc.best_score_)
# Out:
# SGDClassifier(alpha=0.001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)
# 0.780650542118432
# C:\Users\Shche\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
# SVM
svm = SVC(kernel = 'rbf', probability = True)
param_grid = {'C': [5],
             'gamma': [0.01]}
grid_search_svm = GridSearchCV(svm, cv = 10, param_grid = param_grid, scoring = 'accuracy', n_jobs = 3)
grid_search_svm.fit(X_train, train['misogynous'])
print(grid_search_svm.best_estimator_)
print(grid_search_svm.best_score_)
# Out:
# SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 0.7892688351403948

# %%
# gradient boosting
grad_boost = GradientBoostingClassifier()
param_grid = {'n_estimators': [100],
             'max_depth': [10, 15, 20]}
grid_search_grad_boost = GridSearchCV(grad_boost, cv = 10, param_grid = param_grid, scoring = 'accuracy', n_jobs = 3)
grid_search_grad_boost.fit(X_train, train['misogynous'])
print(grid_search_grad_boost.best_estimator_)
print(grid_search_grad_boost.best_score_)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)
# 0.8028912983041423

# %%
# ensemble classifier with soft voting
voting = VotingClassifier(estimators=[('forest', grid_search_forest.best_estimator_),
                                      ('svm', grid_search_svm.best_estimator_),
                                      ('boost', grid_search_grad_boost.best_estimator_),
                                     ('sgd', grid_search_sgdc.best_estimator_),
                                     ('lg', grid_search_lg.best_estimator_)])
param_grid = {'voting': ['soft']}
grid_search_voting = GridSearchCV(voting, cv = 10, param_grid = param_grid, scoring = 'accuracy', n_jobs = 3)
grid_search_voting.fit(X_train, train['misogynous'])
print(grid_search_voting.best_estimator_)
print(grid_search_voting.best_score_)
# Out:
# VotingClassifier(estimators=[('forest', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=175, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min...ty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))],
#          flatten_transform=None, n_jobs=1, voting='soft', weights=None)
# 0.7964970809007507
# C:\Users\Shche\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %% [markdown]
# ## Test

# %%
y_pred = grid_search_grad_boost.predict(X_test)
print("Accuracy:", accuracy_score(test['misogynous'], y_pred))
# Out:
# Accuracy: 0.82

# %%
# save CountVectorizer and the ensemble model
with open('Project Models/BOW_model.pickle', 'wb') as f:
    pickle.dump(grid_search_grad_boost.best_estimator_, f, pickle.HIGHEST_PROTOCOL)
with open('Project Models/Count_vectorizer.pickle', 'wb') as f:
    pickle.dump(count_vect_misogyny, f, pickle.HIGHEST_PROTOCOL)
